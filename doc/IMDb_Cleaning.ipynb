# %% [markdown]
# # Cleaning IMDb dataset for NETS 1500 project
# The following code cleans the relatively small dataset and unwinds lists into atomic records.

# %%
import pandas as pd
import numpy as np

# %%
prefix = '/content/drive'
from google.colab import drive
drive.mount(prefix, force_remount=True)
# Out:
# Mounted at /content/drive

# %%
imdb_path = '/content/drive/My Drive/imdb_dataset.csv'

# %%
imdb_df = pd.read_csv(imdb_path)

# %%
imdb_df.head()
# Out:
#                                      Movie_Title  Year           Director  \
# 0                                        Kantara  2022      Rishab Shetty
# 1                                The Dark Knight  2008  Christopher Nolan
# 2  The Lord of the Rings: The Return of the King  2003      Peter Jackson
# 3                                      Inception  2010  Christopher Nolan
# 4          The Lord of the Rings: The Two Towers  2002      Peter Jackson
#
#                                               Actors  Rating  Runtime(Mins)  \
# 0  Rishab Shetty, Sapthami Gowda, Kishore Kumar G...     9.3            148
# 1  Christian Bale, Heath Ledger, Aaron Eckhart, M...     9.0            152
# 2  Elijah Wood, Viggo Mortensen, Ian McKellen, Or...     9.0            201
# 3  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...     8.8            148
# 4  Elijah Wood, Ian McKellen, Viggo Mortensen, Or...     8.8            179
#
#   Censor   Total_Gross main_genre           side_genre
# ...

# %%
# Transform string of actors into list of actors
imdb_df['Actors'] = imdb_df['Actors'].str.split(", ")
imdb_df
# Out:
#                                         Movie_Title  Year  \
# 0                                           Kantara  2022
# 1                                   The Dark Knight  2008
# 2     The Lord of the Rings: The Return of the King  2003
# 3                                         Inception  2010
# 4             The Lord of the Rings: The Two Towers  2002
# ...                                             ...   ...
# 5557                                 Disaster Movie  2008
# 5558                        The Hottie & the Nottie  2008
# 5559                           From Justin to Kelly  2003
# 5560                   Superbabies: Baby Geniuses 2  2004
# 5561                 Cumali Ceber: Allah Seni Alsin  2017
#
#                                       Director  \
# 0                                Rishab Shetty
# 1                            Christopher Nolan
# 2                                Peter Jackson
# 3                            Christopher Nolan
# ...

# %%
# Expand list of actors
imdb_df = imdb_df.explode('Actors').reset_index(drop=True)
imdb_df
# Out:
#                           Movie_Title  Year           Director  \
# 0                             Kantara  2022      Rishab Shetty
# 1                             Kantara  2022      Rishab Shetty
# 2                             Kantara  2022      Rishab Shetty
# 3                             Kantara  2022      Rishab Shetty
# 4                     The Dark Knight  2008  Christopher Nolan
# ...                               ...   ...                ...
# 22231    Superbabies: Baby Geniuses 2  2004          Bob Clark
# 22232  Cumali Ceber: Allah Seni Alsin  2017         Gökhan Gök
# 22233  Cumali Ceber: Allah Seni Alsin  2017         Gökhan Gök
# 22234  Cumali Ceber: Allah Seni Alsin  2017         Gökhan Gök
# 22235  Cumali Ceber: Allah Seni Alsin  2017         Gökhan Gök
#
#                  Actors  Rating  Runtime(Mins)     Censor   Total_Gross  \
# 0         Rishab Shetty     9.3            148         UA  Gross Unkown
# ...

# %%
# Number of "Not Rated" (just curious)
imdb_df[imdb_df['Censor'] == 'Not Rated'].count()
# Out:
# Movie_Title      1980
# Year             1980
# Director         1980
# Actors           1980
# Rating           1980
# Runtime(Mins)    1980
# Censor           1980
# Total_Gross      1980
# main_genre       1980
# side_genre       1980
# dtype: int64

# %%
# Number of "Gross Unknown" (just curious)
imdb_df[imdb_df['Total_Gross'] == 'Gross Unkown']
# Out:
#                           Movie_Title  Year          Director  \
# 0                             Kantara  2022     Rishab Shetty
# 1                             Kantara  2022     Rishab Shetty
# 2                             Kantara  2022     Rishab Shetty
# 3                             Kantara  2022     Rishab Shetty
# 40                            Seppuku  1962  Masaki Kobayashi
# ...                               ...   ...               ...
# 22215  Enes Batur Hayal mi Gerçek mi?  2018       Kamil Cetin
# 22232  Cumali Ceber: Allah Seni Alsin  2017        Gökhan Gök
# 22233  Cumali Ceber: Allah Seni Alsin  2017        Gökhan Gök
# 22234  Cumali Ceber: Allah Seni Alsin  2017        Gökhan Gök
# 22235  Cumali Ceber: Allah Seni Alsin  2017        Gökhan Gök
#
#                  Actors  Rating  Runtime(Mins)     Censor   Total_Gross  \
# 0         Rishab Shetty     9.3            148         UA  Gross Unkown
# 1        Sapthami Gowda     9.3            148         UA  Gross Unkown
# ...

# %%
imdb_df = imdb_df[imdb_df['Total_Gross'] != 'Gross Unkown']
imdb_df
# Out:
#                                          Movie_Title  Year           Director  \
# 4                                    The Dark Knight  2008  Christopher Nolan
# 5                                    The Dark Knight  2008  Christopher Nolan
# 6                                    The Dark Knight  2008  Christopher Nolan
# 7                                    The Dark Knight  2008  Christopher Nolan
# 8      The Lord of the Rings: The Return of the King  2003      Peter Jackson
# ...                                              ...   ...                ...
# 22227                           From Justin to Kelly  2003      Robert Iscove
# 22228                   Superbabies: Baby Geniuses 2  2004          Bob Clark
# 22229                   Superbabies: Baby Geniuses 2  2004          Bob Clark
# 22230                   Superbabies: Baby Geniuses 2  2004          Bob Clark
# 22231                   Superbabies: Baby Geniuses 2  2004          Bob Clark
#
# ...

# %%
# Checking if they're all grossing in millions
imdb_df['Total_Gross'].str.contains('M').count()
# Out:
# 18794

# %%
total_gross = imdb_df['Total_Gross'].str.replace('\$|M', '', regex=True)

# %%
total_gross.count()
# Out:
# 18794

# %%
imdb_df['Total_Gross'] = imdb_df['Total_Gross'].str.replace('\$|M', '', regex=True)
# Out:
# <ipython-input-220-bbeed5c058bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_df['Total_Gross'] = imdb_df['Total_Gross'].str.replace('\$|M', '', regex=True)

# %%
imdb_df['Total_Gross'] = imdb_df['Total_Gross'].astype(float)
imdb_df.dtypes
# Out:
# <ipython-input-221-3ccb1e116017>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_df['Total_Gross'] = imdb_df['Total_Gross'].astype(float)
# Movie_Title       object
# Year               int64
# Director          object
# Actors            object
# Rating           float64
# Runtime(Mins)      int64
# Censor            object
# Total_Gross      float64
# main_genre        object
# side_genre        object
# dtype: object

# %%
imdb_df
# Out:
#                                          Movie_Title  Year           Director  \
# 4                                    The Dark Knight  2008  Christopher Nolan
# 5                                    The Dark Knight  2008  Christopher Nolan
# 6                                    The Dark Knight  2008  Christopher Nolan
# 7                                    The Dark Knight  2008  Christopher Nolan
# 8      The Lord of the Rings: The Return of the King  2003      Peter Jackson
# ...                                              ...   ...                ...
# 22227                           From Justin to Kelly  2003      Robert Iscove
# 22228                   Superbabies: Baby Geniuses 2  2004          Bob Clark
# 22229                   Superbabies: Baby Geniuses 2  2004          Bob Clark
# 22230                   Superbabies: Baby Geniuses 2  2004          Bob Clark
# 22231                   Superbabies: Baby Geniuses 2  2004          Bob Clark
#
# ...

# %%
imdb_df['Censor'].unique()
# Out:
# array(['UA', 'U', 'A', 'R', 'Not Rated', 'PG', 'PG-13', 'U/A', '7', '16',
#        '18', '(Banned)', '13', '12+', 'UA 16+', '15+', 'UA 13+',
#        'Unrated', 'G', 'M/PG', 'All', 'UA 7+', 'NC-17'], dtype=object)

# %%
# imdb_df['side_genre'] = imdb_df['side_genre'].str.split(", ")

# %%
imdb_df = imdb_df[['Movie_Title', 'Year', 'Director', 'Actors', 'Rating', 'Runtime(Mins)', 'Censor', 'Total_Gross', 'main_genre']]

# %%
imdb_df[imdb_df['Director'].str.contains('Directors:')]
# Out:
#                              Movie_Title  Year  \
# 24                            The Matrix  1999
# 25                            The Matrix  1999
# 26                            The Matrix  1999
# 27                            The Matrix  1999
# 72     Spider-Man: Into the Spider-Verse  2018
# ...                                  ...   ...
# 22207                         Epic Movie  2007
# 22216                     Disaster Movie  2008
# 22217                     Disaster Movie  2008
# 22218                     Disaster Movie  2008
# 22219                     Disaster Movie  2008
#
#                                                 Director              Actors  \
# 24             Directors:Lana Wachowski, Lilly Wachowski        Keanu Reeves
# 25             Directors:Lana Wachowski, Lilly Wachowski  Laurence Fishburne
# 26             Directors:Lana Wachowski, Lilly Wachowski    Carrie-Anne Moss
# 27             Directors:Lana Wachowski, Lilly Wachowski        Hugo Weaving
# ...

# %%
imdb_df['Director'] = imdb_df['Director'].str.replace('Directors:', '', regex=True)
# Out:
# <ipython-input-227-d343a5ddf072>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_df['Director'] = imdb_df['Director'].str.replace('Directors:', '', regex=True)

# %%
imdb_df['Director'] = imdb_df['Director'].str.split(', ')
# Out:
# <ipython-input-228-e66660576b76>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_df['Director'] = imdb_df['Director'].str.split(', ')

# %%
imdb_df = imdb_df.explode('Director').reset_index(drop=True)

# %%
imdb_df
# Out:
#                                          Movie_Title  Year           Director  \
# 0                                    The Dark Knight  2008  Christopher Nolan
# 1                                    The Dark Knight  2008  Christopher Nolan
# 2                                    The Dark Knight  2008  Christopher Nolan
# 3                                    The Dark Knight  2008  Christopher Nolan
# 4      The Lord of the Rings: The Return of the King  2003      Peter Jackson
# ...                                              ...   ...                ...
# 20688                           From Justin to Kelly  2003      Robert Iscove
# 20689                   Superbabies: Baby Geniuses 2  2004          Bob Clark
# 20690                   Superbabies: Baby Geniuses 2  2004          Bob Clark
# 20691                   Superbabies: Baby Geniuses 2  2004          Bob Clark
# 20692                   Superbabies: Baby Geniuses 2  2004          Bob Clark
#
# ...

# %%
imdb_df = imdb_df.reset_index(drop=True)

# %%
imdb_df.to_csv('imdb_cleaned.csv')

# %%
len(imdb_df['Actors'].unique())
# Out:
# 6873

# %%
len(imdb_df['Movie_Title'].unique())
# Out:
# 4628
